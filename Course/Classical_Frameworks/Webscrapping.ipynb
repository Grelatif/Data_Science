# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ElMartinez31/Data_Science/blob/main/Course/Classical_Frameworks/Webscrapping.ipynb)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://books.toscrape.com/catalogue/page-1.html"
page = requests.get(url)

# %%
#page # answer = 200 ok
print(page.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#         <meta name="created" content="24th Jun 2016 09:30" />
#         <meta name="description" content="" />
#         <meta name="viewport" content="width=device-width" />
#         <meta name="robots" content="NOARCHIVE,NOCACHE" />
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#
#
# ...

# %%
item
# Out:
# {'price': '£51.77', 'stock': 'In stock', 'title': 'A Light in the Attic'}

# %%
soup = BeautifulSoup(page.text,"html.parser")

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
soup.title # get page title
# Out:
# <title>
#     All products | Books to Scrape - Sandbox
# </title>

# %%
soup.title.text.strip()
# Out:
# 'All products | Books to Scrape - Sandbox'

# %%
soup.find_all("li", class_ = "col-xs-6 col-sm-4 col-md-3 col-lg-3")
# Out:
# [<li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>
#  </li>,
#  <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# ...

# %%
current_page = 1
url = "https://books.toscrape.com/catalogue/page-"+str(current_page)+".html"
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")

# %%
binary = True
error_code = "404 Not Found"

# %%
current_page = 1
binary = True
liste = []

while binary:
  url = "https://books.toscrape.com/catalogue/page-"+str(current_page)+".html"
  page = requests.get(url)
  soup = BeautifulSoup(page.text, "html.parser")
  #last page break
  if(soup.title.text == error_code):
    break
  else: # add of the current book info
    books = soup.find_all("li", class_ = "col-xs-6 col-sm-4 col-md-3 col-lg-3")
    for book in books:
      item = {}
      item["price"] = book.find("p", class_ ="price_color" ).text.strip()[1:]
      item["stock"] = book.find("p", class_ = "instock availability").text.strip()
      item["title"] = book.find("img").attrs["alt"]

      liste.append(item) # append book to list (list of dict)
    current_page +=1 # increment

# %%
df = pd.DataFrame(liste)

# %%
df ## let's go!!
# Out:
#       price     stock                                              title
# 0    £51.77  In stock                               A Light in the Attic
# 1    £53.74  In stock                                 Tipping the Velvet
# 2    £50.10  In stock                                         Soumission
# 3    £47.82  In stock                                      Sharp Objects
# 4    £54.23  In stock              Sapiens: A Brief History of Humankind
# ..      ...       ...                                                ...
# 995  £55.53  In stock  Alice in Wonderland (Alice's Adventures in Won...
# 996  £57.06  In stock   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997  £16.97  In stock  A Spy's Devotion (The Regency Spies of London #1)
# 998  £53.98  In stock                1st to Die (Women's Murder Club #1)
# 999  £26.08  In stock                 1,000 Places to See Before You Die
#
# [1000 rows x 3 columns]
