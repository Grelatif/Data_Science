# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ElMartinez31/Data_Science/blob/main/Exercices/test_codespace.ipynb)

# %%
import pandas as pd
import numpy as np

# %%
data = np.array([4, 7 , 9])


print(data)
# Out:
# [4 7 9]
