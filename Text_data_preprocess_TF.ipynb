# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentences = ["i enjoy argentina's parilla",
             "i like listening to daft punk",
              "i hate junk food"]

# %%
max_vocab_size = 20000
tokenizer = Tokenizer(num_words=max_vocab_size)
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)

# %%
sequences
# Out:
# [[1, 2, 3, 4], [1, 5, 6, 7, 8, 9], [1, 10, 11, 12]]

# %%
tokenizer.word_index
# Out:
# {'i': 1,
#  'enjoy': 2,
#  "argentina's": 3,
#  'parilla': 4,
#  'like': 5,
#  'listening': 6,
#  'to': 7,
#  'daft': 8,
#  'punk': 9,
#  'hate': 10,
#  'junk': 11,
#  'food': 12}

# %%
data = pad_sequences(sequences) #standadize the number of elements in each sequence
print(data)
# Out:
# [[ 0  0  1  2  3  4]
#  [ 1  5  6  7  8  9]
#  [ 0  0  1 10 11 12]]
